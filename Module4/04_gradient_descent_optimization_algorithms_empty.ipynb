# %% [markdown]
# <a href="https://colab.research.google.com/github/xgpo-2226/EFFDL_Semaine1/blob/main/Module4/04_gradient_descent_optimization_algorithms_empty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Dataflowr](https://raw.githubusercontent.com/dataflowr/website/master/_assets/dataflowr_logo.png)](https://dataflowr.github.io/website/)

# %% [markdown]
# Code adapted from [Optimization chapter](http://www.d2l.ai/chapter_optimization/) of Dive into Deep Learning

# %%
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

def show_trace_2d(f, res , color = 'red'):
    """Show the trace of 2d variables during optimization."""
    x1, x2 = zip(*res)
    plt.plot(x1, x2, '-o', color=color)
    x1 = np.arange(-5.5, 3.5, 0.1)
    x2 = np.arange(min(-3.0, min(x2) - 1), max(1.0, max(x2) + 1), 0.1)
    x1, x2 = np.meshgrid(x1, x2)
    plt.contour(x1, x2, f(x1, x2), colors='blue')
    plt.xlabel('x1')
    plt.ylabel('x2')

# %%
def train_2d(trainer):
    """Optimize the objective function of 2d variables with a customized trainer."""
    """trainer(x1,x2,s_x1,s_x2) should return the updated positions x1, x2 and possible memory terms."""
    x1, x2 = -5, -2
    s_x1, s_x2 = 0, 0
    res = [(x1, x2)]
    for i in range(20):
        x1, x2, s_x1, s_x2 = trainer(x1, x2, s_x1, s_x2)
        res.append((x1, x2))
    print('epoch %d, x1 %f, x2 %f' % (i+1, x1, x2))
    return res

# %% [markdown]
# # Gradient descent
#
# [Video timestamp](https://youtu.be/UvM0hK4E2dc?t=589)

# %%
eta = 0.4

def f_2d(x1, x2):
    return 0.1 * x1 ** 2 + 2 * x2 ** 2

def gd_2d(x1, x2, s1, s2):
    return (x1 - eta * 0.2 * x1, x2 - eta * 4 * x2, 0, 0)

# %%
show_trace_2d(f_2d, train_2d(gd_2d))
# Out:
# epoch 20, x1 -0.943467, x2 -0.000073

# %%
eta = 0.6
show_trace_2d(f_2d, train_2d(gd_2d))
# Out:
# epoch 20, x1 -0.387814, x2 -1673.365109

# %% [markdown]
# # Momemtum
#
# [Video timestamp](https://youtu.be/UvM0hK4E2dc?t=734)

# %%
eta, gamma = 0.4, 0.5

def momentum_2d(x1, x2, v1, v2):
    v1 = gamma * v1 + eta * 0.2 * x1  # using th equation provided in slide 7 of the reference slide (the jocobian is just the first derivative)
    v2 = gamma * v2 + eta * 4 * x2
    return x1 - v1, x2 - v2, v1, v2

# %%
show_trace_2d(f_2d, train_2d(momentum_2d))
# Out:
# epoch 20, x1 -0.062843, x2 0.001202

# %%
eta = 0.6
show_trace_2d(f_2d, train_2d(momentum_2d))
# Out:
# epoch 20, x1 0.007188, x2 0.002553

# %%
eta, gamma = 0.05, 0.9
show_trace_2d(f_2d, train_2d(momentum_2d))
# Out:
# epoch 20, x1 -0.589111, x2 0.698505

# %% [markdown]
# # Nesterov accelerated gradient
#
# [Video timestamp](https://youtu.be/UvM0hK4E2dc?t=938)

# %%
eta, gamma = 0.05, 0.9  # smaller eta = slower convergence but less overshoot

def Nesterov_2d(x1, x2, v1, v2):
    v1 = gamma * v1 + eta * 0.2 * (x1 - gamma * v1)
    v2 = gamma * v2 + eta * 4 * (x2 - gamma * v2)
    return x1 - v1, x2 - v2, v1, v2

# %%
show_trace_2d(f_2d, train_2d(Nesterov_2d))
show_trace_2d(f_2d, train_2d(momentum_2d), color= 'green')
# Out:
# epoch 20, x1 -4.416206, x2 0.389214
# epoch 20, x1 -4.413734, x2 0.541343

# %% [markdown]
# # Adagrad
#
# [Video timestamp](https://youtu.be/UvM0hK4E2dc?t=1080)

# %%
import math

def adagrad_2d(x1, x2, s1, s2):
    # The first two terms are the independent variable gradients
    g1, g2, eps = 0.2 * x1, 4 * x2, 1e-8  # 1e-6
    #
    # your code here (hint: use math.sqrt)
    # Accumulate squared gradients
    s1 += g1 ** 2
    s2 += g2 ** 2

    # Update parameters using Adagrad formula
    x1 -= eta / math.sqrt(s1 + eps) * g1
    x2 -= eta / math.sqrt(s2 + eps) * g2
    return x1, x2, s1, s2

# %%
eta = 0.4   # 0.01 is too small?? not appropriate
show_trace_2d(f_2d, train_2d(adagrad_2d))
# show_trace_2d(f_2d, train_2d(Nesterov_2d), color= 'green')
# show_trace_2d(f_2d, train_2d(momentum_2d), color= 'magenta')
# Out:
# epoch 20, x1 -2.382562, x2 -0.158591

# %%
eta = 2
show_trace_2d(f_2d, train_2d(adagrad_2d))
# show_trace_2d(f_2d, train_2d(Nesterov_2d), color= 'green')
# show_trace_2d(f_2d, train_2d(momentum_2d), color= 'magenta')
# Out:
# epoch 20, x1 -0.002295, x2 -0.000000

# %% [markdown]
# # RMSProp
#
# [Video timestamp](https://youtu.be/UvM0hK4E2dc?t=1206)

# %%
def rmsprop_2d(x1, x2, s1, s2):
    g1, g2, eps = 0.2 * x1, 4 * x2, 1e-6
    #
    # your code here

    # Update the moving average of squared gradients
    s1 = gamma * s1 + (1 - gamma) * g1 ** 2
    s2 = gamma * s2 + (1 - gamma) * g2 ** 2

    # Update parameters using RMSProp formula
    x1 -= eta / math.sqrt(s1 + eps) * g1
    x2 -= eta / math.sqrt(s2 + eps) * g2

    return x1, x2, s1, s2

# %%
eta, gamma = 0.4, 0.9
show_trace_2d(f_2d, train_2d(rmsprop_2d))
# Out:
# epoch 20, x1 -0.010599, x2 0.000000

# %% [markdown]
# # Adam
#
# [Video timestamp](https://youtu.be/UvM0hK4E2dc?t=1331)

# %%
def adam_2d(x1, x2, s1, s2 , t):
    beta1, beta2, eps = 0.9, 0.99, 1e-6
    g1, g2 = 0.2 * x1, 4 * x2
    #
    # your code here
    ## Initialize moment estimates if t == 0
    if t == 0:
        s1 = [0, 0, 0]  # [m1, v1, v1_hat] for x1
        s2 = [0, 0, 0]  # [m2, v2, v2_hat] for x2

    # Update biased first moment estimate
    s1[0] = beta1 * s1[0] + (1 - beta1) * g1
    s2[0] = beta1 * s2[0] + (1 - beta1) * g2

    # Update biased second raw moment estimate v1
    s1[1] = beta2 * s1[1] + (1 - beta2) * (g1 ** 2)
    s2[1] = beta2 * s2[1] + (1 - beta2) * (g2 ** 2)

    # Compute bias-corrected first moment estimate
    m1_hat = s1[0] / (1 - beta1 ** (t + 1))
    m2_hat = s2[0] / (1 - beta1 ** (t + 1))

    # Compute bias-corrected second raw moment estimate
    v1_hat = s1[1] / (1 - beta2 ** (t + 1))
    v2_hat = s2[1] / (1 - beta2 ** (t + 1))

    # Update parameters
    x1 -= eta / (math.sqrt(v1_hat) + eps) * m1_hat
    x2 -= eta / (math.sqrt(v2_hat) + eps) * m2_hat

    # Store the bias-corrected second moment estimates
    s1[2] = v1_hat
    s2[2] = v2_hat

    return x1, x2, s1, s2

# %%
def train_adam_2d(trainer):
    """Optimize the objective function of 2d variables with Adam-li trainer."""
    """trainer(x1,x2,s_x1,s_x2) should return the updated positions x1, x2 and possible memory terms."""
    x1, x2 = -5, -2
    s_x1, s_x2 = [0,0,0], [0,0,0]
    res = [(x1, x2)]
    for i in range(20):
        x1, x2, s_x1, s_x2 = trainer(x1, x2, s_x1, s_x2, i)
        res.append((x1, x2))
    print('epoch %d, x1 %f, x2 %f' % (i+1, x1, x2))
    return res

# %%
eta = 0.8
show_trace_2d(f_2d, train_adam_2d(adam_2d))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-747df6592279> in <cell line: 0>()
#       1 eta = 0.8
# ----> 2 show_trace_2d(f_2d, train_adam_2d(adam_2d))
#
# <ipython-input-67-c7e23dd77867> in train_adam_2d(trainer)
#       6     res = [(x1, x2)]
#       7     for i in range(20):
# ----> 8         x1, x2, s_x1, s_x2 = trainer(x1, x2, s_x1, s_x2, i)
#       9         res.append((x1, x2))
#      10     print('epoch %d, x1 %f, x2 %f' % (i+1, x1, x2))
#
# <ipython-input-66-88cdebf2a904> in adam_2d(x1, x2, s1, s2, t)
#      30
#      31     # Store the bias-corrected second moment estimates
# ---> 32     s1[2] = v1_hat
#      33     s2[2] = v2_hat
#      34
#
# IndexError: list assignment index out of range

# %% [markdown]
# # AMSGrad
#
# [Video timestamp](https://youtu.be/UvM0hK4E2dc?t=1479)

# %%
def amsgrad_2d(x1, x2, s1, s2 , t):
    beta1, beta2, eps = 0.9, 0.99, 1e-6
    g1, g2 = 0.2 * x1, 4 * x2
    #
    # your code here
    #
    return x1, x2, s1, s2

# %%
eta = 1
show_trace_2d(f_2d, train_adam_2d(amsgrad_2d))
show_trace_2d(f_2d, train_adam_2d(adam_2d), color ='green')
# Out:
# epoch 20, x1 -0.977985, x2 -0.470241
# epoch 20, x1 -0.571139, x2 0.487553

# %%
[![Dataflowr](https://raw.githubusercontent.com/dataflowr/website/master/_assets/dataflowr_logo.png)](https://dataflowr.github.io/website/)
